# %%
import pandas as pd

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
data = {
    "Parent" : ["A" , "A","B" , "B"],
    "Child" : ["B" , "C" , "D" , "E"]
    
}

# %%
df = pd.DataFrame(data)

# %%
G = nx.from_pandas_edgelist(df,'Parent' , 'Child')

# %%
fig, ax = plt.subplots() 
pos = nx.spring_layout(G)

nx.draw(G, pos, ax=ax, with_labels=True, node_color='lightblue', node_size=2000, font_size=12)

plt.title("Tree from Dataset            Reg No : -  URK24CS7103")
plt.show()

# %%
import networkx as nx  
import plotly.graph_objects as go

# %%
G = nx.Graph()

G.add_edge("Root","Branch1")
G.add_edge("Root","Branch2")
G.add_edge("Branch1","Leaf1")
G.add_edge("Branch2","Leaf2")
G.add_edge("Branch3","Leaf3")
G.add_edge("Branch4","Leaf4")

# %%
pos = nx.spring_layout(G)

# %%
edge_x = []
edge_y = []

for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

edge_trace = go.Scatter(
    x = edge_x,
    y = edge_y,
    line = dict(width=1, color='#888'),
    mode = 'lines'
)

node_x = []
node_y = []
labels = []

for node in G.nodes():
    x, y = pos[node]
    node_x.append(x) 
    node_y.append(y)
    labels.append(node)

node_trace = go.Scatter(
    x = node_x,
    y = node_y,
    mode = 'markers+text', 
    text = labels,
    textposition = "top center",
    marker = dict(size = 20)
)

fig = go.Figure(data=[edge_trace, node_trace])
fig.update_layout(
    title = "Interactive Tree Explorer          Reg No : - URK24CS7103      ",
)

fig.show()

# %%
datas = {
    "Category": ["Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Home Appliances", "Home Appliances", "Home Appliances", "Home Appliances", "Home Appliances", "Home Appliances", "Home Appliances", "Home Appliances", "Fashion", "Fashion", "Fashion", "Fashion", "Fashion", "Fashion", "Fashion", "Fashion"],
    "Subcategory": ["Mobile Phones", "Mobile Phones", "Mobile Phones", "Laptops", "Laptops", "Laptops", "Accessories", "Accessories", "Accessories", "Kitchen", "Kitchen", "Kitchen", "Cleaning", "Cleaning", "Cleaning", "Cooling", "Cooling", "Men", "Men", "Women", "Women", "Accessories", "Accessories", "Footwear", "Footwear"],
    "Product": ["Android Phones", "iPhones", "Feature Phones", "Gaming Laptop", "Business Laptop", "Student Laptop", "Headphones", "Smart Watch", "Power Bank", "Microwave Oven", "Refrigerator", "Mixer Grinder", "Vacuum Cleaner", "Washing Machine", "Dishwasher", "Air Conditioner", "Air Cooler", "Shirts", "Jeans", "Dresses", "Handbags", "Watches", "Sunglasses", "Sports Shoes", "Casual Shoes"],
    "Sales": [45000, 60000, 15000, 75000, 50000, 42000, 18000, 32000, 12000, 30000, 55000, 22000, 25000, 48000, 40000, 65000, 28000, 20000, 27000, 35000, 30000, 40000, 22000, 38000, 26000]
}

# %%
datas = pd.DataFrame(datas)
datas
# Out:
#            Category    Subcategory          Product  Sales
# 0       Electronics  Mobile Phones   Android Phones  45000
# 1       Electronics  Mobile Phones          iPhones  60000
# 2       Electronics  Mobile Phones   Feature Phones  15000
# 3       Electronics        Laptops    Gaming Laptop  75000
# 4       Electronics        Laptops  Business Laptop  50000
# 5       Electronics        Laptops   Student Laptop  42000
# 6       Electronics    Accessories       Headphones  18000
# 7       Electronics    Accessories      Smart Watch  32000
# 8       Electronics    Accessories       Power Bank  12000
# 9   Home Appliances        Kitchen   Microwave Oven  30000
# 10  Home Appliances        Kitchen     Refrigerator  55000
# 11  Home Appliances        Kitchen    Mixer Grinder  22000
# 12  Home Appliances       Cleaning   Vacuum Cleaner  25000
# 13  Home Appliances       Cleaning  Washing Machine  48000
# 14  Home Appliances       Cleaning       Dishwasher  40000
# ...

# %%
import plotly.express as px
treemap = px.treemap(
    datas,
    path = ["Category" , "Subcategory", "Product"],
    values = "Sales",
    title = "Treemap of product Sales by category              Reg No : - URK24CS7103  "
)

treemap.show()

# %%
sun = px.sunburst(
    datas,
    path = ["Category" , "Subcategory", "Product"],
    values = "Sales",
    title = "Sunburst of product Sales by category                Reg  No : - URK24CS7103                "
)
 
sun.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

data = {"Parent": ["A","A","B","B"], "Child": ["B","C","D","E"]}
df = pd.DataFrame(data)

G = nx.from_pandas_edgelist(df, 'Parent', 'Child', create_using=nx.DiGraph())

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000)

plt.title("Tree")
plt.show()

# %%
import networkx as nx
import plotly.graph_objects as go

G = nx.Graph()
G.add_edges_from([("Root","A"),("Root","B"),("A","C"),("B","D")])

pos = nx.spring_layout(G)

# Edges
edge_x, edge_y = [], []
for e in G.edges():
    x0, y0 = pos[e[0]]
    x1, y1 = pos[e[1]]
    edge_x += [x0, x1, None]
    edge_y += [y0, y1, None]

edge_trace = go.Scatter(x=edge_x, y=edge_y, mode='lines')

# Nodes
node_x, node_y, labels = [], [], []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)
    labels.append(node)

node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    mode='markers+text',
    text=labels,
    textposition="top center"
)

# Combine
fig = go.Figure(data=[edge_trace, node_trace])
fig.show()

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    "Category": ["Electronics","Electronics","Home"],
    "Sub": ["Phones","Laptops","Kitchen"],
    "Value": [100,150,80]
})

px.treemap(df, path=["Category","Sub"], values="Value").show()
px.sunburst(df, path=["Category","Sub"], values="Value").show()
